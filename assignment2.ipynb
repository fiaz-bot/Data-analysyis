# %%
import numpy as np
import statistics
import pandas as pd

# %%
#csv file
dfo=pd.read_csv("ActivityData.csv")

# %%
dfo
# Out:
#      1654788999-345278656547333     2     Phone Call- Unnamed: 3
# 0    1888777222-345278666547334   0.0            SMS-          Y
# 1    1122765445-345278676547335  10.0  Internet Data-        NaN
# 2    1356753668-345278686547336   1.0  Phone Call-111        NaN
# 3    1590741891-345278696547337   2.0  Phone Call-111        NaN
# 4    1824730114-345278706547338   3.0  Phone Call-111        NaN
# ..                          ...   ...             ...        ...
# 994  1526695270-345283606547828  12.0  Internet Data-        NaN
# 995  1526695271-345283616547829  15.0  Internet Data-        NaN
# 996  1526695272-345283626547830  16.0  Internet Data-        NaN
# 997  1526695273-345283636547831  17.0  Internet Data-        NaN
# 998  1526695274-345283646547832  18.0  Internet Data-        NaN
#
# [999 rows x 4 columns]

# %%
df=pd.DataFrame(dfo)
df
# Out:
#      1654788999-345278656547333     2     Phone Call- Unnamed: 3
# 0    1888777222-345278666547334   0.0            SMS-          Y
# 1    1122765445-345278676547335  10.0  Internet Data-        NaN
# 2    1356753668-345278686547336   1.0  Phone Call-111        NaN
# 3    1590741891-345278696547337   2.0  Phone Call-111        NaN
# 4    1824730114-345278706547338   3.0  Phone Call-111        NaN
# ..                          ...   ...             ...        ...
# 994  1526695270-345283606547828  12.0  Internet Data-        NaN
# 995  1526695271-345283616547829  15.0  Internet Data-        NaN
# 996  1526695272-345283626547830  16.0  Internet Data-        NaN
# 997  1526695273-345283636547831  17.0  Internet Data-        NaN
# 998  1526695274-345283646547832  18.0  Internet Data-        NaN
#
# [999 rows x 4 columns]

# %%
df2=df.rename(columns={'1654788999-345278656547333':'PhoneNumber-SubscriberIdentityNumber'})

# %%
print(df2)
# Out:
#     PhoneNumber-SubscriberIdentityNumber     2     Phone Call- Unnamed: 3
# 0             1888777222-345278666547334   0.0            SMS-          Y
# 1             1122765445-345278676547335  10.0  Internet Data-        NaN
# 2             1356753668-345278686547336   1.0  Phone Call-111        NaN
# 3             1590741891-345278696547337   2.0  Phone Call-111        NaN
# 4             1824730114-345278706547338   3.0  Phone Call-111        NaN
# ..                                   ...   ...             ...        ...
# 994           1526695270-345283606547828  12.0  Internet Data-        NaN
# 995           1526695271-345283616547829  15.0  Internet Data-        NaN
# 996           1526695272-345283626547830  16.0  Internet Data-        NaN
# 997           1526695273-345283636547831  17.0  Internet Data-        NaN
# 998           1526695274-345283646547832  18.0  Internet Data-        NaN
#
# [999 rows x 4 columns]

# %%
df3=df.rename(columns={'2':'Duration'})
print(df3)
df.to_csv("output.csv")
# Out:
#      1654788999-345278656547333  Duration     Phone Call- Unnamed: 3
# 0    1888777222-345278666547334       0.0            SMS-          Y
# 1    1122765445-345278676547335      10.0  Internet Data-        NaN
# 2    1356753668-345278686547336       1.0  Phone Call-111        NaN
# 3    1590741891-345278696547337       2.0  Phone Call-111        NaN
# 4    1824730114-345278706547338       3.0  Phone Call-111        NaN
# ..                          ...       ...             ...        ...
# 994  1526695270-345283606547828      12.0  Internet Data-        NaN
# 995  1526695271-345283616547829      15.0  Internet Data-        NaN
# 996  1526695272-345283626547830      16.0  Internet Data-        NaN
# 997  1526695273-345283636547831      17.0  Internet Data-        NaN
# 998  1526695274-345283646547832      18.0  Internet Data-        NaN
#
# [999 rows x 4 columns]

# %%
df4=df.rename(columns={'Phone Call-':'Activity'})
print(df4)
# Out:
#      1654788999-345278656547333     2        Activity Unnamed: 3
# 0    1888777222-345278666547334   0.0            SMS-          Y
# 1    1122765445-345278676547335  10.0  Internet Data-        NaN
# 2    1356753668-345278686547336   1.0  Phone Call-111        NaN
# 3    1590741891-345278696547337   2.0  Phone Call-111        NaN
# 4    1824730114-345278706547338   3.0  Phone Call-111        NaN
# ..                          ...   ...             ...        ...
# 994  1526695270-345283606547828  12.0  Internet Data-        NaN
# 995  1526695271-345283616547829  15.0  Internet Data-        NaN
# 996  1526695272-345283626547830  16.0  Internet Data-        NaN
# 997  1526695273-345283636547831  17.0  Internet Data-        NaN
# 998  1526695274-345283646547832  18.0  Internet Data-        NaN
#
# [999 rows x 4 columns]

# %%
df5=df.rename(columns={'Unnamed: 3':'ErrorCode'})
print(df5)
# Out:
#      1654788999-345278656547333     2     Phone Call- ErrorCode
# 0    1888777222-345278666547334   0.0            SMS-         Y
# 1    1122765445-345278676547335  10.0  Internet Data-       NaN
# 2    1356753668-345278686547336   1.0  Phone Call-111       NaN
# 3    1590741891-345278696547337   2.0  Phone Call-111       NaN
# 4    1824730114-345278706547338   3.0  Phone Call-111       NaN
# ..                          ...   ...             ...       ...
# 994  1526695270-345283606547828  12.0  Internet Data-       NaN
# 995  1526695271-345283616547829  15.0  Internet Data-       NaN
# 996  1526695272-345283626547830  16.0  Internet Data-       NaN
# 997  1526695273-345283636547831  17.0  Internet Data-       NaN
# 998  1526695274-345283646547832  18.0  Internet Data-       NaN
#
# [999 rows x 4 columns]

# %%
df7=df.rename(columns={'Phone Call-':'Activity','Unnamed: 3':'ErrorCode','2':'Duration','1654788999-345278656547333':'PhoneNumber-SubscriberIdentityNumber'}
              )
df7
# Out:
#     PhoneNumber-SubscriberIdentityNumber  Duration        Activity ErrorCode
# 0             1888777222-345278666547334       0.0            SMS-         Y
# 1             1122765445-345278676547335      10.0  Internet Data-       NaN
# 2             1356753668-345278686547336       1.0  Phone Call-111       NaN
# 3             1590741891-345278696547337       2.0  Phone Call-111       NaN
# 4             1824730114-345278706547338       3.0  Phone Call-111       NaN
# ..                                   ...       ...             ...       ...
# 994           1526695270-345283606547828      12.0  Internet Data-       NaN
# 995           1526695271-345283616547829      15.0  Internet Data-       NaN
# 996           1526695272-345283626547830      16.0  Internet Data-       NaN
# 997           1526695273-345283636547831      17.0  Internet Data-       NaN
# 998           1526695274-345283646547832      18.0  Internet Data-       NaN
#
# [999 rows x 4 columns]

# %%
df.to_csv("kilo.csv")

# %%
df[['Activity_1','Activity_2']] = df['Activity'].str.split('-', expand = True)

# %%
df
# Out:
#     PhoneNumber-SubscriberIdentityNumber  Duration        Activity ErrorCode  \
# 0             1888777222-345278666547334       0.0            SMS-         Y
# 1             1122765445-345278676547335      10.0  Internet Data-       NaN
# 2             1356753668-345278686547336       1.0  Phone Call-111       NaN
# 3             1590741891-345278696547337       2.0  Phone Call-111       NaN
# 4             1824730114-345278706547338       3.0  Phone Call-111       NaN
# ..                                   ...       ...             ...       ...
# 994           1526695270-345283606547828      12.0  Internet Data-       NaN
# 995           1526695271-345283616547829      15.0  Internet Data-       NaN
# 996           1526695272-345283626547830      16.0  Internet Data-       NaN
# 997           1526695273-345283636547831      17.0  Internet Data-       NaN
# 998           1526695274-345283646547832      18.0  Internet Data-       NaN
#
#         Activity_1 Activity_2
# ...

# %%
df.head(10)
# Out:
#   PhoneNumber-SubscriberIdentityNumber  Duration        Activity ErrorCode  \
# 0           1888777222-345278666547334       0.0            SMS-         Y
# 1           1122765445-345278676547335      10.0  Internet Data-       NaN
# 2           1356753668-345278686547336       1.0  Phone Call-111       NaN
# 3           1590741891-345278696547337       2.0  Phone Call-111       NaN
# 4           1824730114-345278706547338       3.0  Phone Call-111       NaN
# 5           1058718337-345278716547339       4.0  Phone Call-111       NaN
# 6           1292706560-345278726547340       5.0     Phone Call-       NaN
# 7           1526694783-345278736547341      12.0     Phone Call-       NaN
# 8           1526694784-345278746547342      11.0     Phone Call-       NaN
# 9           1526694785-345278756547343      10.0     Phone Call-       NaN
#
#       Activity_1 Activity_2
# 0            SMS
# 1  Internet Data
# 2     Phone Call        111
# 3     Phone Call        111
# ...

# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
tui=pd.read_csv("kilo.csv")

# %%
tui
# Out:
#      Unnamed: 0 PhoneNumber-SubscriberIdentityNumber  Duration  \
# 0             0           1888777222-345278666547334       0.0
# 1             1           1122765445-345278676547335      10.0
# 2             2           1356753668-345278686547336       1.0
# 3             3           1590741891-345278696547337       2.0
# 4             4           1824730114-345278706547338       3.0
# ..          ...                                  ...       ...
# 994         994           1526695270-345283606547828      12.0
# 995         995           1526695271-345283616547829      15.0
# 996         996           1526695272-345283626547830      16.0
# 997         997           1526695273-345283636547831      17.0
# 998         998           1526695274-345283646547832      18.0
#
#            Activity ErrorCode
# 0              SMS-         Y
# 1    Internet Data-       NaN
# 2    Phone Call-111       NaN
# 3    Phone Call-111       NaN
# 4    Phone Call-111       NaN
# ...

# %%
tui.isnull()
# Out:
#      Unnamed: 0  PhoneNumber-SubscriberIdentityNumber  Duration  Activity  \
# 0         False                                 False     False     False
# 1         False                                 False     False     False
# 2         False                                 False     False     False
# 3         False                                 False     False     False
# 4         False                                 False     False     False
# ..          ...                                   ...       ...       ...
# 994       False                                 False     False     False
# 995       False                                 False     False     False
# 996       False                                 False     False     False
# 997       False                                 False     False     False
# 998       False                                 False     False     False
#
#      ErrorCode
# 0        False
# 1         True
# 2         True
# ...

# %%
tui['ErrorCode'].fillna(0, inplace=True)

# %%
tui
# Out:
#      Unnamed: 0 PhoneNumber-SubscriberIdentityNumber  Duration  \
# 0             0           1888777222-345278666547334       0.0
# 1             1           1122765445-345278676547335      10.0
# 2             2           1356753668-345278686547336       1.0
# 3             3           1590741891-345278696547337       2.0
# 4             4           1824730114-345278706547338       3.0
# ..          ...                                  ...       ...
# 994         994           1526695270-345283606547828      12.0
# 995         995           1526695271-345283616547829      15.0
# 996         996           1526695272-345283626547830      16.0
# 997         997           1526695273-345283636547831      17.0
# 998         998           1526695274-345283646547832      18.0
#
#            Activity ErrorCode
# 0              SMS-         Y
# 1    Internet Data-         0
# 2    Phone Call-111         0
# 3    Phone Call-111         0
# 4    Phone Call-111         0
# ...

# %%
sns.distplot(tui['Unnamed: 0'])
plt.xlabel('Duration')
plt.ylabel('Activity')
plt.show()
# Out:
# C:\Users\PC\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
duplicates=tui.duplicated()
print(f"Number of duplicates rows:{duplicates.sum()}")

if duplicates.sum() > 0:
    print("Duplicate rows")
    print(df[duplicates])
    
    df_cleaned=df.drop_duplicates()
    
    print(f"Number of duplicate rows after removal: {df_cleaned.duplicated().sum()}")
    
    df_cleaned.to_csv('voi.csv')
# Out:
# Number of duplicates rows:0

# %%
tui.to_csv("voi.csv")

# %%
import pandas as pd

# %%
dData= pd.read_csv("voi.csv")
dData.head(10)
# Out:
#    Unnamed: 0.1  Unnamed: 0 PhoneNumber-SubscriberIdentityNumber  Duration  \
# 0             0           0           1888777222-345278666547334       0.0
# 1             1           1           1122765445-345278676547335      10.0
# 2             2           2           1356753668-345278686547336       1.0
# 3             3           3           1590741891-345278696547337       2.0
# 4             4           4           1824730114-345278706547338       3.0
# 5             5           5           1058718337-345278716547339       4.0
# 6             6           6           1292706560-345278726547340       5.0
# 7             7           7           1526694783-345278736547341      12.0
# 8             8           8           1526694784-345278746547342      11.0
# 9             9           9           1526694785-345278756547343      10.0
#
#          Activity ErrorCode
# 0            SMS-         Y
# 1  Internet Data-       NaN
# 2  Phone Call-111       NaN
# ...

# %%
df=pd.DataFrame(dData)
df
# Out:
#      Unnamed: 0.1  Unnamed: 0 PhoneNumber-SubscriberIdentityNumber  Duration  \
# 0               0           0           1888777222-345278666547334       0.0
# 1               1           1           1122765445-345278676547335      10.0
# 2               2           2           1356753668-345278686547336       1.0
# 3               3           3           1590741891-345278696547337       2.0
# 4               4           4           1824730114-345278706547338       3.0
# ..            ...         ...                                  ...       ...
# 994           994         994           1526695270-345283606547828      12.0
# 995           995         995           1526695271-345283616547829      15.0
# 996           996         996           1526695272-345283626547830      16.0
# 997           997         997           1526695273-345283636547831      17.0
# 998           998         998           1526695274-345283646547832      18.0
#
#            Activity ErrorCode
# ...

# %%
df=df.drop(['Unnamed: 0.1','Unnamed: 0'],axis=1)
df
# Out:
#     PhoneNumber-SubscriberIdentityNumber  Duration ErrorCode
# 0             1888777222-345278666547334       0.0         Y
# 1             1122765445-345278676547335      10.0       NaN
# 2             1356753668-345278686547336       1.0       NaN
# 3             1590741891-345278696547337       2.0       NaN
# 4             1824730114-345278706547338       3.0       NaN
# ..                                   ...       ...       ...
# 994           1526695270-345283606547828      12.0       NaN
# 995           1526695271-345283616547829      15.0       NaN
# 996           1526695272-345283626547830      16.0       NaN
# 997           1526695273-345283636547831      17.0       NaN
# 998           1526695274-345283646547832      18.0       NaN
#
# [999 rows x 3 columns]

# %%
df.to_csv('f.csv')

# %%
df
# Out:
#     PhoneNumber-SubscriberIdentityNumber  Duration ErrorCode
# 0             1888777222-345278666547334       0.0         Y
# 1             1122765445-345278676547335      10.0       NaN
# 2             1356753668-345278686547336       1.0       NaN
# 3             1590741891-345278696547337       2.0       NaN
# 4             1824730114-345278706547338       3.0       NaN
# ..                                   ...       ...       ...
# 994           1526695270-345283606547828      12.0       NaN
# 995           1526695271-345283616547829      15.0       NaN
# 996           1526695272-345283626547830      16.0       NaN
# 997           1526695273-345283636547831      17.0       NaN
# 998           1526695274-345283646547832      18.0       NaN
#
# [999 rows x 3 columns]
